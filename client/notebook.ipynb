# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/mattiesanseverino/Downloads/landfills_xy.csv")
info = pd.read_csv("/Users/mattiesanseverino/Downloads/landfill_info.csv")

# %%
grouped_df = df.groupby('SWIS').agg({'Longitude (Decimal Degrees)': list, 'Latitude (Decimal Degrees)': list}).reset_index()

# %%
joined_df = pd.merge(grouped_df, info, on='SWIS', how='outer')
joined_df.head()
# Out:
#          SWIS                        Longitude (Decimal Degrees)  \
# 0  01-AA-0001  [122.086476, 122.08398170000001, 122.082102900...
# 1  01-AA-0006  [122.1967746, 122.19372959999998, 122.19146210...
# 2  01-AA-0008  [121.99635959999999, 121.988295, 121.991694999...
# 3  01-AA-0011  [122.3119327, 122.3150361, 122.316125, 122.317...
# 4  01-AA-0012  [122.2267763, 122.2267317, 122.22813670000001,...
#
#                           Latitude (Decimal Degrees)  \
# 0  [37.581434200000004, 37.5767105, 37.5769416000...
# 1  [37.713497499999995, 37.7090385, 37.7043999, 3...
# 2  [37.498418799999996, 37.4908525, 37.488385, 37...
# 3  [37.890025200000004, 37.889509600000004, 37.88...
# 4  [37.7480251, 37.745512299999994, 37.7455122999...
#
#                                        Landfill Name Latitude  Longitude  \
# 0                                   Turk Island Land  37.5786  -122.0858
# 1                     Davis Street Sanitary Landfill  37.7144  -122.1948
# 2                    Tri Cities Recycling & Disposal  37.4928  -121.9923
# 3                                    Albany Landfill  37.8898  -122.3113
# 4  City Of Alameda SW II-2 Disposal Site / Doolit...  37.7470  -122.2340
#
#                            Physical Address         City State      Zip  ...  \
# 0                32505 Union City Boulevard   Union City    CA  94587.0  ...
# 1                     W End of Davis Street  San Leandro    CA  94577.0  ...
# 2                       7010 Auto Mall Pkwy      Fremont    CA  94538.0  ...
# 3                        W End Buchanan St.       Albany    CA  94706.0  ...
# 4  N Side Doolittle Dr @ Br To Alameda Isl.      Alameda    CA  94502.0  ...
#
#                              Year Range if not Exact Waste in Place (Tons)  \
# 0  This landfill consisted of three separate parc...                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  Reports say the dump opened in 1963 but the Ci...                   NaN
# 4                                                NaN                   NaN
#
#          Converted Conversion Type          Site Conversion   \
# 0    Not Converted             NaN                       NaN
# 1  Fully Converted          Public  Oyster Bay Regional Park
# 2    Not Converted             NaN                       NaN
# 3  Fully Converted          Public               Albany Bulb
# 4    Not Converted             NaN                       NaN
#
#   Site Regulartory Status                                 Documentation Name  \
# 0             Surrendered  Post Closure Land Use Proposal and Work Plan -...
# 1               Permitted      Focused Feasibility Study Leachate Management
# 2               Permitted        Final Closure/Post-Closure Maintenance Plan
# 3               Permitted                                                NaN
# 4               Permitted                                                NaN
#
#                                   Documentation Link  Documentation Site  \
# 0  https://secure.calrecycle.ca.gov/SWISDocument/...         Cal Recycle
# 1  https://secure.calrecycle.ca.gov/SWISDocument/...         Cal Recycle
# 2  https://secure.calrecycle.ca.gov/SWISDocument/...         Cal Recycle
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#                                   SWIS Documentation
# 0  https://www2.calrecycle.ca.gov/SolidWaste/Site...
# 1  https://www2.calrecycle.ca.gov/SolidWaste/Site...
# 2  https://www2.calrecycle.ca.gov/SolidWaste/Site...
# 3  https://www2.calrecycle.ca.gov/SolidWaste/Site...
# 4  https://www2.calrecycle.ca.gov/SolidWaste/Site...
#
# [5 rows x 30 columns]

# %%
#joined_df['SWIS'] = grouped_df['SWIS'].apply(lambda x: f'"{x}"')
#joined_df['Longitude (Decimal Degrees)'] = grouped_df['Longitude (Decimal Degrees)'].apply(lambda x: f'"{x}"')
#joined_df['Latitude (Decimal Degrees)'] = grouped_df['Latitude (Decimal Degrees)'].apply(lambda x: f'"{x}"')
for col in joined_df.columns:
    joined_df[col] = joined_df[col].apply(lambda x: f'"{x}"')
final_df = joined_df[['SWIS', 'Longitude (Decimal Degrees)', 'Latitude (Decimal Degrees)', 'Landfill Name', 'City', 'Landfill Ownership Type', 'Owner', 'Class', 'Type of Waste', 'Type of Waste 2 (Supporting Info)', 'Current Landfill Status', 'Year Opened', 'Year Closed', 'Year Range if not Exact', 'Converted', 'Conversion Type', 'Site Conversion ', 'Site Regulartory Status', 'Documentation Link']]

# %%
final_df.head()
# Out:
#            SWIS                        Longitude (Decimal Degrees)  \
# 0  "01-AA-0001"  "[122.086476, 122.08398170000001, 122.08210290...
# 1  "01-AA-0006"  "[122.1967746, 122.19372959999998, 122.1914621...
# 2  "01-AA-0008"  "[121.99635959999999, 121.988295, 121.99169499...
# 3  "01-AA-0011"  "[122.3119327, 122.3150361, 122.316125, 122.31...
# 4  "01-AA-0012"  "[122.2267763, 122.2267317, 122.22813670000001...
#
#                           Latitude (Decimal Degrees)  \
# 0  "[37.581434200000004, 37.5767105, 37.576941600...
# 1  "[37.713497499999995, 37.7090385, 37.7043999, ...
# 2  "[37.498418799999996, 37.4908525, 37.488385, 3...
# 3  "[37.890025200000004, 37.889509600000004, 37.8...
# 4  "[37.7480251, 37.745512299999994, 37.745512299...
#
#                                        Landfill Name           City  \
# 0                                 "Turk Island Land"   "Union City"
# 1                   "Davis Street Sanitary Landfill"  "San Leandro"
# 2                  "Tri Cities Recycling & Disposal"      "Fremont"
# 3                                  "Albany Landfill"       "Albany"
# 4  "City Of Alameda SW II-2 Disposal Site / Dooli...      "Alameda"
#
#   Landfill Ownership Type                                              Owner  \
# 0               "Private"                              "Turk Island Company"
# 1        "Private/Public"  "Oakland Scanvenger Company / Waste Management...
# 2                "Public"               "Waste Management of Alameda County"
# 3                "Public"                                   "City of Albany"
# 4                "Public"                                  "City of Alameda"
#
#                     Class          Type of Waste  \
# 0             "Class III"  "Non-hazardous Waste"
# 1             "Class III"  "Non-Hazardous Waste"
# 2  "Class II / Class III"                  "nan"
# 3             "Class III"  "Non-Hazardous Waste"
# 4             "Class III"  "Non-Hazardous Waste"
#
#   Type of Waste 2 (Supporting Info) Current Landfill Status Year Opened  \
# 0                             "nan"                "Closed"    "1962.0"
# 1                             "nan"                "Closed"    "1940.0"
# 2                             "nan"                "Closed"    "1967.0"
# 3                             "nan"                "Closed"    "1963.0"
# 4                             "nan"                "Closed"    "1953.0"
#
#   Year Closed                            Year Range if not Exact  \
# 0    "1986.0"  "This landfill consisted of three separate par...
# 1    "1984.0"                                              "nan"
# 2    "2012.0"                                              "nan"
# 3    "1983.0"  "Reports say the dump opened in 1963 but the C...
# 4    "1985.0"                                              "nan"
#
#            Converted Conversion Type            Site Conversion   \
# 0    "Not Converted"           "nan"                       "nan"
# 1  "Fully Converted"        "Public"  "Oyster Bay Regional Park"
# 2    "Not Converted"           "nan"                       "nan"
# 3  "Fully Converted"        "Public"               "Albany Bulb"
# 4    "Not Converted"           "nan"                       "nan"
#
#   Site Regulartory Status                                 Documentation Link
# 0           "Surrendered"  "https://secure.calrecycle.ca.gov/SWISDocument...
# 1             "Permitted"  "https://secure.calrecycle.ca.gov/SWISDocument...
# 2             "Permitted"  "https://secure.calrecycle.ca.gov/SWISDocument...
# 3             "Permitted"                                              "nan"
# 4             "Permitted"                                              "nan"

# %%
#final_df.to_csv('grouped_xy_with_info.csv', index=False)

# %%
# Count the number of True and False per name
counts = final_df['Class'].value_counts()
print(counts)
# Out:
# "nan"                               69
# "Class III"                         59
# "Class I"                           14
# "Class II"                          12
# "Class I/Class II"                   3
# "Class II/Class III"                 1
# "Inert Waste/Class III"              1
# "Class II / Class III"               1
# "Class I / Class III"                1
# "Class I / Class II / Class III"     1
# Name: Class, dtype: int64

# %%
counts.to_csv('class_counts.csv')

# %%
ownership_counts = final_df['Landfill Ownership Type'].value_counts()
print(ownership_counts)
# Out:
# "Private"           71
# "Public"            55
# "nan"               30
# "Public/Private"     5
# "Private/Public"     1
# Name: Landfill Ownership Type, dtype: int64

# %%
ownership_counts.to_csv('ownership_counts.csv')
